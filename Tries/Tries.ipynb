# %% [markdown]
# #### Best Videos for Tries concepts(https://www.youtube.com/watch?v=KJVQeyLQKbc)

# %% [markdown]
# #### A Trie is a tree based data structure that organizes information in a hierarchy. It is typically used to store or search(fast pre-fix searches) strings in space and time efficient way.
# #### Unlike binary trees where every Node can have atmost 2 children, Tries can have multiple children to at any Node.
# #### Every Node stores link of the next char of the string and keeps the track of 'End of the String'

# %%
from typing import List
import heapq

# %%
# https://leetcode.com/problems/implement-trie-prefix-tree/
class TrieNode:
    def __init__(self):
        self.children = {}
        self.end_of_word = False
class Trie:
    def __init__(self):
        self.root = TrieNode()
    def insert(self, word: str) -> None:
        node = self.root
        for ch in word:
            if ch not in node.children:
                node.children[ch] = TrieNode()
            node = node.children[ch]
        node.end_of_word = True
    def search(self, word: str) -> bool:
        node = self._traverse(word)
        return node is not None and node.end_of_word
    def startsWith(self, prefix: str) -> bool:
        return self._traverse(prefix) is not None
    def _traverse(self, word: str) -> TrieNode:
        node = self.root
        for ch in word:
            if ch not in node.children:
                return None
            node = node.children[ch]
        return node

# %%
# https://leetcode.com/problems/design-add-and-search-words-data-structure/
class TrieNode:
    def __init__(self):
        self.children = {}
        self.isEnd = False

class WordDictionary:
    def __init__(self):
        self.root = TrieNode()

    def addWord(self, word: str) -> None:
        node = self.root
        for ch in word:
            if ch not in node.children:
                node.children[ch] = TrieNode()
            node = node.children[ch]

        node.isEnd = True

    def search(self, word: str) -> bool:
        def dfs(index, node):
            # Base case: reached end of word
            if index == len(word):
                return node.isEnd
            ch = word[index]
            # Case 1: normal character
            if ch != ".":
                if ch not in node.children:
                    return False
                return dfs(index + 1, node.children[ch])
            # Case 2: wildcard '.'
            for child in node.children.values():
                if dfs(index + 1, child):
                    return True
            return False
        return dfs(0, self.root)

# %%
# https://leetcode.com/problems/longest-word-in-dictionary/description/
def longestWord(self, words: List[str]) -> str:
        # Sort by length, then lexicographically
        words.sort()
        valid = set()
        answer = ""
        for word in words:
            # Base case: single character word
            # Or prefix exists
            print(word[:-1])
            if len(word) == 1 or word[:-1] in valid:
                valid.add(word)
                # Update answer
                if len(word) > len(answer):
                    answer = word
        return answer

# ALTERNATIVE TRIE SOLUTION BUT COMPLEX
class TrieNode:
    def __init__(self):
        self.children = {}
        self.isEnd = False


class Solution:
    def longestWord(self, words: List[str]) -> str:
        # Step 1: Build Trie
        root = TrieNode()

        for word in words:
            node = root
            for ch in word:
                if ch not in node.children:
                    node.children[ch] = TrieNode()
                node = node.children[ch]
            node.isEnd = True

        self.answer = ""

        # Step 2: DFS
        def dfs(node, path):
            # Update answer
            if len(path) > len(self.answer) or (len(path) == len(self.answer) and path < self.answer):
                self.answer = path

            for ch, child in node.children.items():
                # Only continue if prefix is valid word
                if child.isEnd:
                    dfs(child, path + ch)

        dfs(root, "")
        return self.answer
